# %%
import h5py
import matplotlib.pyplot as plt

# %%
GW190725_174728

# %%
IGWN-GWTC2p1-v2-GW190725_174728_PEDataRelease_mixed_cosmo.h5

# %%
IGWN-GWTC2p1-v2-GW190725_174728_PEDataRelease_mixed_nocosmo.h5
