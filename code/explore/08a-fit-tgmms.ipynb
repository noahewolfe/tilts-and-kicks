# %%
import h5ify
import matplotlib.pyplot as plt
from truncatedgaussianmixtures import fit_gmm, Transformation
# Out:
# Detected Jupyter notebook. Loading juliacall extension. Set `PYSR_AUTOLOAD_EXTENSIONS=no` to disable.
# The juliacall extension is already loaded. To reload it, use:
#   %reload_ext juliacall
# Installing TruncatedGaussianMixtures
#      Cloning git-repo `https://github.com/Potatoasad/TruncatedGaussianMixtures.jl`
#     Updating git-repo `https://github.com/Potatoasad/TruncatedGaussianMixtures.jl`
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
# ┌ Warning: failed to extract archive downloaded from https://pkg.julialang.org/package/7d9f7c33-5ae7-4f3b-8dc6-eff91059b697/856ecd7cebb68e5fc87abecd2326ad59f0f911f3
# └ @ Pkg.Operations ~/.conda/envs/just-for-kicks/julia_env/pyjuliapkg/install/share/julia/stdlib/v1.12/Pkg/src/Operations.jl:793
# ┌ Warning: failed to extract archive downloaded from https://pkg.julialang.org/package/163ba53b-c6d8-5494-b064-1a9d43ac40c5/782dd5f4561f5d267313f23853baaaa4c52ea621
# ...
