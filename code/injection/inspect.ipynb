# %%
import h5ify
import numpy as np
from util import plot_corner

# %%
r = h5ify.load(
    '/n/home03/newolfe/projects/tilts-and-kicks/data/inference/injection/tests/260207/nobs70-seed1702-ulin/extras.h5'
)

# %%
fig = plot_corner(
    np.column_stack([
        r['xi_spin'],
        r['sigma_spin'],
        r['mu_spin'],
        r['variance']
    ]),
    truths=[
        0.3,
        1e-2,
        1,
        0,
    ],
    labels=[
        'xi_spin',
        'sigma_spin',
        'mu_spin',
        'variance'
    ]
);
