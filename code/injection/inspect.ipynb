# %%
import h5ify
import numpy as np
from util import plot_corner

# %%
r = h5ify.load(
    '/n/home03/newolfe/projects/tilts-and-kicks/data/inference/injection/tests/260207/seed44/extras.h5'
)

# %%
fig = plot_corner(
    np.column_stack([
        r['lamb'],
        r['variance']
    ])
);
